# %%
import os 
import folium
from folium import plugins

# %%
m = folium.Map(location=[50.450001, 30.523333],tiles = 'Stamen Terrain')

# %%
pt_of_interest = [(50.342613, 30.892525), (49.921496314, 36.287332184),(49.81250, 23.95583),(48.07333, 37.73944),
                  (48.25917, 25.98056),(46.67556, 32.50639),(47.86694, 35.31556),(48.35694, 35.10056),
                 (46.42667, 30.67639),(50.40167, 30.44944),(48.88417, 24.68583),(45.05194, 33.97500)]

# %%
for i in pt_of_interest : 
    folium.Marker(location=i, popup='Airport', icon=folium.Icon(color='green')).add_to(m)

# %%
russians = [(46.751345, 36.790809),(50.8735190, 30.0022539),(51.018381, 30.029615),(51.0180406, 30.0316221),
            (46.754746, 36.793654),(50.54257331282061, 30.227966904370003),(46.751345, 36.790809),(50.950552, 29.880903),
           (47.26803437722594, 37.780175133439826),(49.71691535134674, 37.608891853835026),(50.00992657523523, 36.284383806944845),
           (46.65502, 32.65695),(50.593381, 30.204936),(43.3184915, 45.6933000),(56.07350,29.90667),(46.964200, 32.026888),
           (46.839600, 35.374024),(51.985890, 29.160549),(46.678419, 32.719509),(46.839817, 35.371137),(51.985890, 29.160549),
           (51.018381, 30.029615),(50.891586, 29.976228),(50.0022, 29.4003),(50.003357, 36.332974),(50.028497, 36.362763),
           (50.03010293205669, 36.35787347789866),(50.6437502, 29.9331862),(48.8918, 24.69768)]

# %%
for i in russians : 
        folium.Marker(location=i, popup="Comfirmed Russian(or affiliate)", icon=folium.Icon(color='red')).add_to(m)

# %%
cam = [(50.4499982, 30.521164582),(49.842957,24.031111)]

# %%
for i in cam : 
            folium.Marker(location=i, popup='Webcam', icon=folium.Icon(color='gray')).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
